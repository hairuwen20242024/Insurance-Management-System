# %% [markdown]
# # WEEK1 : Overview and project set up (Angular & Spring Boot)

# %% [markdown]
# ## Tasks
#
# 1. look at how the basic concept of insurance policy management work.focus on:
#  - Underwriting for motor policy
#  - claims process
#  - accounting (invoices, claim rations , bordereaux)
#
# 2. Ensure you have all the necessary tools Java SDK, IntelliJ, MySQL, Visual Studio Code, Node.js and postman installed on your machine on your machine
# 3. look at the fundamentals of Angular and Springboot
# 4. Create a new Angular project and set up the initial structure.
# 5. Create a Spring Boot application and set up basic REST endpoints.
# 6. Connect Angular frontend to Spring Boot backend with a simple API call.

# %% [markdown]
# ## Task Implementation
#
# ### Task 1: Basic Concept of Insurance Policy Manageme
#
# #### Overview of Insurance Policy Management
#
# 1. **Introduction**
#    - Define insurance policy management.
#    - Explain the importance of effective insurance policy management for insurance companies.
#    - Discuss the overall workflow of insurance policy manageme#nt.
#
# ### Underwriting for Motor Policy
#
# 1. **Definition and Purpose**
#    - Define underwriting in the context of motor insurance.
#    - Explain the purpose of underwriting, which is to assess the risk and determine the premium for the policy.
#
# 2. **Underwriting Steps**
#
#    2.1 **Risk Assessment**
#    - **Driver Information**:
#      - Collect driving history, including accidents, violations, and claims history.
#      - Analyze age, gender, and experience of the driver.
#    - **Vehicle Information**:
#      - Gather details about the vehicle, such as make, model, age, and condition.
#      - Evaluate safety features and usage patterns (e.g., personal vs. commercial use).
#    - **Geographical Information**:
#      - Assess the location where the vehicle is primarily used and parked.
#      - Consider factors like crime rates, weather conditions, and road quality.
#
#    2.2 **Rate Calculation**
#    - **Premium Calculation**:
#      - Use risk assessment data to calculate the base premium.
#      - Apply discounts and surcharges based on specific criteria (e.g., safe driver discounts, high-risk area surcharges).
#    - **Pricing Models**:
#      - Explain different pricing models, such as experience rating and predictive modeling.
#      - Discuss the role of actuaries in setting premium rates.
#
#    2.3 **Policy Terms and Conditions**
#    - **Coverage Limits**:
#      - Define the maximum amount the insurer will pay for covered losses.
#    - **Deductibles**:
#      - Explain the amount the policyholder must pay out of pocket before the insurance kicks in.
#    - **Exclusions**:
#      - List scenarios and conditions not covered by the policy (e.g., intentional damage, wear and tear).
#
# 3. **Underwriting Tools and Techniques**
#    - **Data Analytics**:
#      - Use of big data and analytics to predict risks and set premiums.
#    - **Machine Learning**:
#      - Implementation of machine learning algorithms to improve risk assessment and underwriting decisions.
#    - **Automated Underwriting Systems**:
#      - Deploy systems that streamline the underwriting proces#s, reduce human error, and improve efficiency.
#
# ### Claims Process
#
# 1. **Definition and Types of Claims**
#    - Define what an insurance claim is.
#    - Explain the different types of claims, such as collision claims, comprehensive claims, liability claims, and personal injury claims.
#
# 2. **Claims Processing Steps**
#
#    2.1 **Claims Submission**
#    - **Filing a Claim**:
#      - Describe the process of submitting a claim, including necessary forms and documentation (e.g., police reports, photos, medical bills).
#    - **Initial Review**:
#      - Explain the initial review process, where the insurer verifies the policy coverage and the claim's validity.
#
#    2.2 **Investigation and Evaluation**
#    - **Claims Investigation**:
#      - Discuss how claims adjusters investigate the circumstances of the claim, including interviewing witnesses and reviewing evidence.
#    - **Damage Assessment**:
#      - Explain how damage to the vehicle or property is assessed, often involving professional appraisers.
#    - **Liability Determination**:
#      - Describe how liability is determined, especially in cases involving multiple parties.
#
#    2.3 **Claims Decision**
#    - **Approval**:
#      - Detail the process of approving a claim and determining the payout amount.
#    - **Partial Payment**:
#      - Explain situations where partial payment is made and why (e.g., shared fault).
#    - **Denial**:
#      - Outline common reasons for claim denial and the process for disputing a denial.
#
#    2.4 **Payment and Settlement**
#    - **Payment Processing**:
#      - Describe how the insurer processes payments to the policyholder or repair shops.
#    - **Settlement Agreement**:
#      - Explain the settlement agreement process, ensuring both parties agree to the terms of the claim resolution.
#
# 3. **Claims Management Systems**
#    - **Software Solutions**:
#      - Discuss different claims management software that helps streamline the claims process.
#    - **Automation and AI**:
#      - Explain how automation and# artificial intelligence are used to improve efficiency and accuracy in claims handling.
#
# ### Accounting in Insurance
#
# 1. **Invoice Processing**
#    - **Premium Invoices**:
#      - Explain the process of generating and sending premium invoices to policyholders.
#    - **Claims Invoices**:
#      - Describe how claims invoices are managed, including payments to third-party service providers (e.g., repair shops, medical providers).
#
# 2. **Claims Ratios**
#    - **Loss Ratio**:
#      - Define loss ratio and its importance in assessing the profitability of insurance policies.
#      - Discuss how loss ratios are calculated (i.e., incurred losses divided by earned premiums).
#    - **Expense Ratio**:
#      - Define expense ratio and its role in evaluating the insurer's operational efficiency.
#      - Explain how expense ratios are calculated (i.e., operating expenses divided by written premiums).
#
# 3. **Bordereaux**
#    - **Definition and Purpose**:
#      - Explain what a bordereau is and its role in reporting detailed information about policies, claims, and premiums to reinsurers or other stakeholders.
#    - **Types of Bordereaux**:
#      - Discuss different types of bordereaux, such as premium bordereaux and claims bordereaux.
#    - **Management and Reporting**:
#      - Describe how bordereomprehensive and informative PDF document on insurance policy management. If you need further assistance or specific examples, please let me know!splayed successfully.

# %% [markdown]
# ### Detailed Steps for Fundamentals of Angular and Spring Boot with Component Search
#
# #### Task 3: Fundamentals of Angular and Spring Boot
#
# #### Angular Fundamentals
#
# 1. **Introduction to Angular**
#    - Angular is a platform and framework for building client-side applications using HTML, CSS, and TypeScript.
#    - Developed and maintained by Google, Angular is widely used for creating dynamic and single-page applications (##### SPAs).
#
# 2. **Core Concepts**
#
#    2.1 **Components**
#    - **Definition**: Components are the fundamental building blocks of Angular applications. Each component consists of an HTML template, a TypeScript class, and optional CSS styles.
#    - **Structure**:
#      - **Template**: Defines the view of the component using HTML.
#      - **Class**: Contains the logic and data for the component.
#      - **Styles**: Optional CSS styles specific to the component.
#    - **Example**:
#      ```typescript
#      import { Component } from '@angular/core';
#
#      @Component({
#        selector: 'app-hello-world',
#        template: `<h1>Hello, World!</h1>`,
#        styles: [`h1 { font-family: Lato; }`]
#      })
#      export class HelloWorldComponent {
#        // Component logic
#      }
#      ```
#
#    2.2 **Modules**
#    - **Definition**: Modules are used to organize an Angular application into cohesive blocks of functionality. Every Angular application has at least one module, the root module.
#    - **Structure**:
#      - **Imports**: Other Angular modules that this module depends on.
#      - **Declarations**: Components, directives, and pipes that belong to this module.
#      - **Providers**: Services that the module uses.
#      - **Bootstrap**: The root component that Angular creates and inserts into the index.html host web page.
#    - **Example**:
#      ```typescript
#      import { NgModule } from '@angular/core';
#      import { BrowserModule } from '@angular/platform-browser';
#      import { AppComponent } from './app.component';
#      import { HelloWorldComponent } from './hello-world/hello-world.component';
#
#      @NgModule({
#        declarations: [
#          AppComponent,
#          HelloWorldComponent
#        ],
#        imports: [
#          BrowserModule
#        ],
#        providers: [],
#        bootstrap: [AppComponent]
#      })
#      export class AppModule { }
#      ```
#
#    2.3 **Templates**
#    - **Definition**: Templates define the HTML view of a component and can use Angular's template syntax for binding data and handling user interactions.
#    - **Binding Syntax**:
#      - **Interpolation**: `{{ expression }}`
#      - **Property Binding**: `[property]="expression"`
#      - **Event Binding**: `(event)="handler"`
#      - **Two-way Binding**: `[(ngModel)]="property"`
#    - **Example**:
#      ```html
#      <h1>{{ title }}</h1>
#      <button (click)="onClick()">Click me</button>
#      <input [(ngModel)]="userInput">
#      ```
#
#    2.4 **Services**
#    - **Definition**: Services are used to share data and logic across multiple components. They are typically used for business logic, data fetching, and other operations.
#    - **Dependency Injection**: Angular uses dependency injection to provide services to components and other services.
#    - **Example**:
#      ```typescript
#      import { Injectable } from '@angular/core';
#
#
#       getData() {
#         return ['Data 1', 'Data 2', 'Data 3'];
#       }
#     }
#    ```lication to check if the message is displayed successfully and the search component works.
#
# These detailed steps will guide you through creating a comprehensive Angular and Spring Boot application, including the ability to search for Angular components.

# %% [markdown]
# ##### 3. **commonly used Angular UI component libs that can be used to build modern and responsive user interfaces**
#
# .
# 3.1. **Angular Material**:
#    - Officially maintained UI component library based on Google's Material Design guidelines.
#    - Provides a rich set of components such as buttons, input fields, cards, dialogs, menus, etc.
#    - Official Documentation: [Angular Material](https://material.angular3..io/)
#
# 3.2. **NG-ZORRO**:
#    - Angular component library based on Ant Design, providing rich and aesthetically pleasing UI components.
#    - Suitable for enterprise-level application development.
#    - Official Documentation: [NG-ZORRO](https://ng.an3.t.design/)
#
# 3.3. **PrimeNG**:
#    - Offers a comprehensive set of UI components, including tables, charts, input controls, dialogs, etc.
#    - Supports theme customization and responsive design.
#    - Official Documentation: [PrimeNG](https://www.primeface3.s.org/primeng/)
#
# 3.4. **Nebular**:
#    - Angular UI library based on the Eva Design System.
#    - Provides a large number of customizable components and modules.
#    - Official Documentation: [Nebular](https://akveo3..github.io/nebular/)
#
# 3.5. **DevExtreme Angular Components**:
#    - Provides advanced components like data grids, charts, data editors, etc.
#    - Suitable for data-intensive applications.
#    - Official Documentation: [DevExtreme Angular Components](https://js.devexpre3.ss.com/Overview/Angular/)
#
# 3.6. **Kendo UI for Angular**:
#    - Offers professional-grade UI components, including grids, charts, schedulers, input controls, etc.
#    - Suitable for complex and high-performance enterprise applications.
#    - Official Documentation: [Kendo UI for Angular](https://www#####l4 **erik.com/kendo-angular-ui)ww.t##el4. **erik.com/kendo-angular-ui)any further questions or need additional assistance, please let me know!

# %% [markdown]
# ##### 4. **Installation and Usage Example of Angular Material**
#
# 4.1. **Install Angular Material**:
#    ```bash
#    ng add @angular/material
#    ```
#
# 4.2. **Choose a theme and set up global typography and animations**.
#
# 4.3. **Use Angular Material Components**:
#    - Import the necessary Material modules in `app.module.ts`:
#      ```typescript
#      import { MatButtonModule } from '@angular/material/button';
#      import { MatInputModule } from '@angular/material/input';
#      import { MatFormFieldModule } from '@angular/material/form-field';
#      import { BrowserAnimationsModule } from '@angular/platform-browser/animations';
#
#      @NgModule({
#        declarations: [
#          AppComponent,
#          SearchComponent
#        ],
#        imports: [
#          BrowserModule,
#          HttpClientModule,
#          BrowserAnimationsModule,
#          MatFormFieldModule,
#          MatInputModule,
#          MatButtonModule
#        ],
#        providers: [],
#        bootstrap: [AppComponent]
#      })
#      export class AppModule { }
#      ```
#
# 4.4. **Use Material Components in a Component**:
#    ```html
#    <!-- search.component.html -->
#    <mat-form-field>
#      <input matInput (input)="applyFilter($event.target.value)" placeholder="Search">
#    </mat-form-field>
#    <div *ngFor="let item of filteredComponents">
#      {{ item }}
#    </div>
#    <button mat-raised-button color="primary">Primary Button</button>
#    ```
#
# 4.5. **Implement Search Functionality in the Component Logic**:
#    ```typescript
#    // search.component.ts
#    import { Component } from '@angular/core';
#
#    @Component({
#      selector: 'app-search',
#      templateUrl: './search.component.html',
#      styleUrls: ['./search.component.css']
#    })
#    export class SearchComponent {
#      components = ['Button', 'Card', 'Dialog', 'Grid', 'List', 'Menu', 'Tabs', 'Toolbar'];
#      filteredComponents = this.components;
#
#      applyFilter(filterValue: string) {
#        this.filteredComponents = this.components.filter(component =>
#          component.toLowerCwe ).includes(filterValue.toLowrCase())
#        );
#      }
#    }
#    ```

# %% [markdown]
# #### Spring Boot Fundamentals
#
# 1. **Introduction to Spring Boot**
#    - Spring Boot is an extension of the Spring framework that simplifies the creation of production-ready applications.
#    - It provides auto-configuration, embedded servers, and a set of conventions over configuration.
#
# 2. **Core Concepts**
#
#    2.1 **Controllers**
#    - **Definition**: Controllers handle HTTP requests and map them to specific handler methods.
#    - **Annotations**:
#      - `@RestController`: Indicates that the class is a controller where every method returns a domain object instead of a view.
#      - `@RequestMapping`: Maps HTTP requests to handler methods.
#    - **Example**:
#      ```java
#      package com.example.demo;
#
#      import org.springframework.web.bind.annotation.GetMapping;
#      import org.springframework.web.bind.annotation.RestController;
#
#      @RestController
#      public class HelloController {
#          @GetMapping("/hello")
#          public String sayHello() {
#              return "Hello, World!";
#          }
#      }
#      ```
#
#    2.2 **Services**
#    - **Definition**: Services contain business logic and are typically used to interact with repositories and other components.
#    - **Annotations**:
#      - `@Service`: Indicates that the class is a service component.
#    - **Example**:
#      ```java
#      package com.example.demo;
#
#      import org.springframework.stereotype.Service;
#
#      @Service
#      public class HelloService {
#          public String getHelloMessage() {
#              return "Hello, World!";
#          }
#      }
#      ```
#
#    2.3 **Repositories**
#    - **Definition**: Repositories handle data access and persistence.
#    - **Annotations**:
#      - `@Repository`: Indicates that the class is a repository component.
#      - `@Query`: Allows defining custom queries.
#    - **Example**:
#      ```java
#      package com.example.demo;
#
#      import org.springframework.data.jpa.repository.JpaRepository;
#      import org.springframework.stereotype.Repository;
#
#   implement**:
#    - Start the Spring Boot backend.
#    - Start the Angular frontend, and navigate to the application to check if the message is displayed successfully and the search component works.
#
# These detailed steps will guide you through creating a comprehensive Angular and Spring Boot application, including the ability to search for Angular components.

# %% [markdown]
# ### Task 4: Create a New Angular Project and Set Up Initial Structure
# 1. **Install Angular CLI**:
#    ```bash
#    npm install -g @angular/cli
#    ```
#
# 2. **Create New Project**:
#    ```bash
#    ng new my-angular-app
#    cd my-angular-app
#    ```
#
# 3. **Set Up Project Structure**:
#    - **src/app**: Contains the main application code.
#    - **src/assets**: Stores static assets.
#    - **src/environments**: Configures environment variables for different environments.
#
# 4. **Start Development Server**:
#    ```bash
#    ng serve
#    ```
#    Open the browser and navigate to `http://localhost:4200` to check if the project is running successfully.

# %% [markdown]
# ### Task 5: Create a Spring Boot Application and Set Up Basic REST Endpoints
# 1. **Create Spring Boot Project**:
#    - Use Spring Initializr to create a new project, selecting the necessary dependencies (e.g., Spring Web).
#
# 2. **Set Up Project Structure**:
#    - **src/main/java/com/example/demo**: Contains the main application code.
#    - **src/main/resources**: Contains configuration files (e.g., `application.properties`).
#
# 3. **Create REST Controller**:
#    ```java
#    package com.example.demo;
#
#    import org.springframework.web.bind.annotation.GetMapping;
#    import org.springframework.web.bind.annotation.RestController;
#
#    @RestController
#    public class HelloController {
#        @GetMapping("/hello")
#        public String sayHello() {
#            return "Hello, World!";
#        }
#    }
#    ```
#
# 4. **Run Application**:
#    - Use an IDE or command line to run the Spring Boot application.
#    - Navigate to `http://localhost:8080/hello` to check if the response is returned successfully.

# %% [markdown]
# ### Task 5: Create a Spring Boot Application and Set Up Basic REST Endpoints
#
# Let's start from downloading the Spring Boot project from Spring Initializr and go through the entire process step-by-step.
#
# #### Step 1: Download Spring Boot Project Using Spring Initializr
#
# 1. **Navigate to Spring Initializr**:
#    - Open your browser and go to [Spring Initializr](https://start.spring.io/).
#
# 2. **Configure Project Settings**:
#    - **Project**: Maven Project
#    - **Language**: Java
#    - **Sprin3 Boo: 3.0.2 (or the latest stable version)
#    - **Project Metadata**:
#      - **Group**: com.example
#      - **Artifact**: demo
#      - **Name**: demo
#      - **Package Name**: com.example.demo
#      - **Packaging**: Jar
#      - **Java Version**: 17 (or the version you have installed)
#    - **Dependencies**: Add `Spring Web`
#
# 3. **Generate Project**:
#    - Click on the "Generate" button to download the project as a ZIP file.
#
# 4. **Extract the Project**:
#    - Extract the downloaded ZIP file to a desired location on your computer.
#
# #### Step 2: Open the Project in Your IDE
#
# 1. **Open Your IDE**:
#    - Open your preferred IDE (IntelliJ IDEA, Eclipse, VS Code, etc.).
#
# 2. **Import the Project**:
#    - Import the extracted Maven project into your IDE.
#
# #### Step 3: Set Up Project Structure
#
# By default, the project structure should look like this:
# ```
# demo
# ├── src
# │   ├── main
# │   │   ├── java
# │   │   │   └── com
# │   │   │       └── example
# │   │   │           └── demo
# │   │   │               ├── DemoApplication.java
# │   │   └── resources
# │   │       └── application.properties
# │   └── test
# │       ├── java
# │       │   └── com
# │       │       └── example
# │       │           └── demo
# │       │               └── DemoApplicationTests.java
# │       └── resources
# ├── mvnw
# ├── mvnw.cmd
# ├── pom.xml
# └── README.md
# ```
#
# #### Step 4: Create REST Controller
#
# 1. **Create a New Controller**:
#    - Create a new Java class named `HelloController` in the `src/main/java/com/example/demo` directory.
#
# 2. **Add REST Endpoint**:
#    - Add a simple REST endpoint that returns "Hello, World!".
#
# ```java
# // src/main/java/com/example/demo/HelloController.java
# package com.example.demo;
#
# import org.springframework.web.bind.annotation.GetMapping;
# import org.springframework.web.bind.annotation.RestController;
#
# @RestController
# public class HelloController {
#     @GetMapping("/hello")
#     public String sayHello() {
#         return "Hello, World!";
#     }
# }
# ```
#
# #### Step 5: Run the Spring Boot Application
#
# 1. **Run the Application**:
#    - Use your IDE to run the `DemoApplication` class.
#
# 2. **Verify the Endpoint**:
#    - Open your browser and navigate to `http://localhost:8080/hello`.
#    - You should see the message "Hello, World!".
#
# #### Step 6: Project Structure Overview
#
# The final project structure should look like this:
# ```
# demo
# ├── src
# │   ├── main
# │   │   ├── java
# │   │   │   └── com
# │   │   │       └── example
# │   │   │           └── demo
# │   │   │               ├── DemoApplication.java
# │   │   │               └── HelloController.java
# │   │   └── resources
# │   │       └── application.properties
# │   └── test
# │       ├── java
# │       │   └── com
# │       │       └── example
# │       │           └── demo
# │       │               └── DemoApplicationTests.java
# │       └── resources
# ├── mvnw
# ├── mvnw.cmd
# ├── pom.xml
# └── README.md
# ```
#
# ### Summary
#
# You have successfully created a Spring Boot application, set up a basic REST endpoint, and verified that the endpoint works. If you encounter any issues or need further assistance, please let me know!

# %% [markdown]
# ### Task 6: Connect Angular Frontend to Spring Boot Backend with a Simple API Call
# 1. **Create Angular Service**:
#    ```typescript
#    import { Injectable } from '@angular/core';
#    import { HttpClient } from '@angular/common/http';
#    import { Observable } from 'rxjs';
#
#    @Injectable({
#      providedIn: 'root'
#    })
#    export class ApiService {
#      private apiUrl = 'http://localhost:8080';
#
#      constructor(private http: HttpClient) { }
#
#      getHelloMessage(): Observable<string> {
#        return this.http.get(`${this.apiUrl}/hello`, { responseType: 'text' });
#      }
#    }
#    ```
#
# 2. **Modify Angular Component**:
#    ```typescript
#    import { Component, OnInit } from '@angular/core';
#    import { ApiService } from './api.service';
#
#    @Component({
#      selector: 'app-root',
#      template: '<h1>{{ message }}</h1>'
#    })
#    export class AppComponent implements OnInit {
#      message: string;
#
#      constructor(private apiService: ApiService) { }
#
#      ngOnInit() {
#        this.apiService.getHelloMessage().subscribe(data => {
#          this.message = data;
#        });
#      }
#    }
#    ```ort class AppComponent implements OnInit {
#      message: string;
#
#      constructor(private apiService: ApiService) { }
#
#      ngOnInit() {
#        this.apiService.getHelloMessage().subscribe(data => {
#          this.message = data;
#        });
#      }
#    }
#    ```
#
# 3. **Update Angular App Module**:
#    ```typescript
#    import { BrowserModule } from '@angular/platform-browser';
#    import { NgModule } from '@angular/core';
#    import { HttpClientModule } from '@angular/common/http';
#
#    import { AppComponent } from './app.component';
#    import
# 4. **Start Applications**:
#    - Start the Spring Boot backend.
#    - Start the Angular frontend, and navigate to the application to check if the message is displayed successfully.
